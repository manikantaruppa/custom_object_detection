# %%
#Run these commads in windows powershell
'''git clone https://github.com/ultralytics/yolov5
cd yolov5
pip install -r requirements.txt'''
# Out:
# 'git clone https://github.com/ultralytics/yolov5\ncd yolov5\npip install -r requirements.txt'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#uploading the training data and annotations into single zip file
#The following commmand used to unzip the file
# !unzip "/content/train_data.zip" -d '/content/train_data'/
# Out:
# Archive:  /content/train_data.zip
#    creating: /content/train_data/train_data/images/
#    creating: /content/train_data/train_data/images/train/
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_01_53_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_02_13_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_02_23_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_02_33_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_02_44_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_02_54_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_03_04_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_03_14_Pro.jpg
#   inflating: /content/train_data/train_data/images/train/WIN_20210103_20_03_24_Pro.jpg
# ...

# %%
# Train YOLOv5s on custom_data for 100 epochs
! python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 5 --epochs 100 --data custom_data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=drive/MyDrive/yolov5/data/hyps/hyp.scratch.yaml, epochs=100, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=drive/MyDrive/yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 4 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-133-g4fb6dd4 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# #### The accuracy of training data is around 98%

# %%
! pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 11.3 MB/s
# ...
#      |████████████████████████████████| 180 kB 31.0 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 140 kB 50.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=a422ef00a32dd3bd50ff50331a3b45b950d23df8b1712e48983e4c4480791bed
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=3d30196d1640b7c92b4736c5837bb5874029693f3b9c0b15ce13bab74b091523
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
#validation on test data

# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp24/weights/best.pt --img 640 --conf 0.1 --source /content/training_data/Training_dataset2/images/val
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp24/weights/best.pt'], source=/content/train_data/train_data/images/val, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-133-g4fb6dd4 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7020913 parameters, 0 gradients
# image 1/20 /content/train_data/train_data/images/val/WIN_20210103_20_20_10_Pro.jpg: 480x640 1 hand, 1 cup, 1 marker, 1 ball, Done. (0.032s)
# image 2/20 /content/train_data/train_data/images/val/WIN_20210103_20_20_46_Pro.jpg: 480x640 1 cup, 1 marker, 1 ball, Done. (0.030s)
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('drive/MyDrive/yolov5/runs/detect/exp13/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
from google.colab import files
files.download('/content/drive/MyDrive/yolov5/runs/train/exp24/weights/best.pt')
